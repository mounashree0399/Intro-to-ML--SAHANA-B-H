# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/4458_8204_bundle_archive (2).zip')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
dataset.corr()['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %%
plt.plot(dataset['quality'], dataset['alcohol'], 'r+')
plt.xlabel('quality')
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')

# %%
x = dataset.iloc[: ,:-1].values
y = dataset.iloc[: , -1].values

# %%
x
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  3.42 ,  0.75 , 11.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  3.57 ,  0.71 , 10.2  ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  3.39 ,  0.66 , 11.   ]])

# %%
y
# Out:
# array([5, 5, 5, ..., 6, 5, 6])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
# array([[12.8 ,  0.3 ,  0.74, ...,  3.2 ,  0.77, 10.8 ],
#        [ 6.  ,  0.5 ,  0.  , ...,  3.36,  0.45,  9.5 ],
#        [ 6.1 ,  0.32,  0.25, ...,  3.42,  0.97, 10.6 ],
#        ...,
#        [ 8.9 ,  0.28,  0.45, ...,  3.25,  0.55, 12.3 ],
#        [10.3 ,  0.32,  0.45, ...,  3.23,  0.82, 12.6 ],
#        [ 9.9 ,  0.32,  0.56, ...,  3.15,  0.73, 11.4 ]])

# %%
x_test
# Out:
# array([[7.60e+00, 7.15e-01, 0.00e+00, ..., 3.48e+00, 6.50e-01, 1.14e+01],
#        [6.30e+00, 3.00e-01, 4.80e-01, ..., 3.44e+00, 7.80e-01, 1.03e+01],
#        [1.09e+01, 3.70e-01, 5.80e-01, ..., 3.22e+00, 7.80e-01, 1.01e+01],
#        ...,
#        [9.40e+00, 3.00e-01, 5.60e-01, ..., 3.15e+00, 9.20e-01, 1.17e+01],
#        [7.10e+00, 6.00e-01, 1.00e-02, ..., 3.40e+00, 6.10e-01, 1.09e+01],
#        [9.20e+00, 5.90e-01, 2.40e-01, ..., 3.26e+00, 6.70e-01, 9.60e+00]])

# %%
y_train
# Out:
# array([7, 5, 5, ..., 7, 8, 6])

# %%
y_test
# Out:
# array([6, 6, 5, 7, 6, 5, 6, 6, 6, 5, 5, 6, 6, 5, 5, 6, 6, 6, 6, 5, 5, 7,
#        6, 7, 6, 6, 7, 6, 7, 5, 7, 5, 5, 6, 6, 6, 6, 7, 5, 5, 6, 5, 6, 6,
#        6, 6, 7, 7, 6, 6, 7, 6, 7, 5, 5, 5, 5, 6, 5, 5, 6, 5, 6, 6, 3, 7,
#        6, 5, 5, 6, 7, 5, 6, 5, 5, 5, 5, 6, 5, 7, 6, 7, 6, 6, 5, 5, 6, 6,
#        5, 5, 5, 5, 6, 5, 4, 7, 6, 7, 7, 7, 6, 5, 4, 6, 5, 6, 6, 6, 8, 7,
#        7, 5, 5, 5, 6, 6, 4, 4, 4, 6, 5, 6, 6, 5, 6, 5, 6, 6, 6, 6, 5, 4,
#        5, 5, 6, 6, 5, 5, 5, 5, 6, 6, 5, 6, 5, 8, 5, 5, 6, 6, 5, 5, 7, 5,
#        5, 7, 6, 7, 6, 6, 5, 5, 6, 6, 6, 6, 5, 6, 6, 5, 5, 5, 6, 5, 5, 5,
#        6, 6, 6, 6, 7, 5, 6, 8, 6, 5, 5, 7, 5, 6, 6, 6, 5, 6, 7, 7, 7, 5,
#        6, 5, 6, 6, 5, 5, 5, 5, 5, 7, 6, 7, 6, 6, 8, 6, 5, 5, 7, 5, 5, 5,
#        6, 5, 4, 6, 4, 4, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5, 5, 5, 6, 4, 7,
#        6, 7, 5, 6, 8, 6, 5, 5, 5, 5, 4, 6, 5, 6, 6, 5, 5, 6, 6, 7, 6, 5,
#        7, 6, 6, 6, 5, 4, 5, 5, 6, 5, 7, 6, 5, 5, 5, 5, 6, 5, 5, 6, 6, 5,
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
x1train = y_train.reshape(len(y_train),1)
x1test = y_test.reshape(len(y_test),1)

# %%
x1train
# Out:
# array([[7],
#        [5],
#        [5],
#        ...,
#        [5],
#        [5],
#        [7]])

# %%
x1test
# Out:
# array([[7],
#        [6],
#        [6],
#        [5],
#        [7],
#        [5],
#        [5],
#        [6],
#        [6],
#        [6],
#        [5],
#        [6],
#        [6],
#        [5],
#        [6],
#        [7],
#        [5],
#        [5],
#        [5],
#        [6],
#        [6],
#        [5],
#        [5],
#        [6],
#        [7],
#        [4],
#        [7],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [6],
#        [5],
#        [6],
#        [5],
#        [5],
#        [5],
#        [6],
#        [5],
#        [5],
#        [6],
#        [6],
#        [5],
#        [5],
#        [5],
#        [5],
#        [6],
#        [5],
#        [6],
#        [6],
#        [5],
#        [6],
#        [7],
#        [5],
#        [6],
#        [5],
#        [6],
#        [5],
#        [6],
#        [6],
#        [5],
#        [6],
#        [6],
#        [6],
#        [5],
#        [6],
#        [7],
#        [6],
#        [5],
# ...

# %%
x_sc = StandardScaler()
y_sc = StandardScaler()

# %%
xx1_train = x_sc.fit_transform(x_train)
yx1_train = y_sc.fit_transform(x1train)

# %%
xx1_test = x_sc.transform(x_test)
yx1_test = y_sc.transform(x1test)

# %%
len(xx1_train)
# Out:
# 1279

# %%
xx1_train
# Out:
# array([[ 2.60351486, -1.25042055,  2.40962537, ..., -0.72153379,
#          0.67479039,  0.34372709],
#        [-1.32740704, -0.14574924, -1.39393371, ...,  0.31551267,
#         -1.23713908, -0.87459531],
#        [-1.26959937, -1.13995342, -0.10894754, ...,  0.70440509,
#          1.86974632,  0.15629288],
#        ...,
#        [ 0.34901553, -1.36088768,  0.9190414 , ..., -0.39745677,
#         -0.63966112,  1.74948372],
#        [ 1.15832298, -1.13995342,  0.9190414 , ..., -0.52708758,
#          0.97352938,  2.03063504],
#        [ 0.92709228, -1.13995342,  1.48443532, ..., -1.04561081,
#          0.43579921,  0.90602974]])

# %%
len(xx1_test)
# Out:
# 320

# %%
xx1_test
# Out:
# array([[-0.40248424,  1.04177241, -1.39393371, ...,  1.09329752,
#         -0.04218316,  0.90602974],
#        [-1.15398402, -1.25042055,  1.07323974, ...,  0.8340359 ,
#          0.73453819, -0.12485845],
#        [ 1.50516903, -0.8637856 ,  1.58723422, ..., -0.59190299,
#          0.73453819, -0.31229266],
#        ...,
#        [ 0.63805391, -1.25042055,  1.48443532, ..., -1.04561081,
#          1.57100734,  1.18718107],
#        [-0.69152262,  0.40658641, -1.34253427, ...,  0.57477429,
#         -0.28117434,  0.4374442 ],
#        [ 0.52243856,  0.35135284, -0.16034699, ..., -0.33264137,
#          0.07731243, -0.7808782 ]])

# %%
yx1_train
# Out:
# array([[ 1.67175957],
#        [-0.81160918],
#        [-0.81160918],
#        ...,
#        [-0.81160918],
#        [-0.81160918],
#        [ 1.67175957]])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import PolynomialFeatures

# %%
r_reg = RandomForestRegressor()
l_reg = LinearRegression()
d_reg = DecisionTreeRegressor()
s_reg = SVR()
p_reg = LinearRegression()

# %%
x_pol = PolynomialFeatures(degree=1)
x_pol = x_pol.fit_transform(xx1_train)

# %%
temp = PolynomialFeatures(degree=1)
temp = temp.fit_transform(xx1_test)

# %%
r_reg.fit(xx1_train, yx1_train)
l_reg.fit(xx1_train, yx1_train)
d_reg.fit(xx1_train, yx1_train)
s_reg.fit(xx1_train, yx1_train)
p_reg.fit(x_pol, yx1_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
r_pred = r_reg.predict(xx1_test)
l_pred = l_reg.predict(xx1_test)
d_pred = d_reg.predict(xx1_test)
s_pred = s_reg.predict(xx1_test)
p_pred = p_reg.predict(temp)

# %%
from sklearn.metrics import r2_score

# %%
r = r2_score(yx1_test, r_pred)
l = r2_score(yx1_test, l_pred)
d = r2_score(yx1_test, d_pred)
s = r2_score(yx1_test, s_pred)
p = r2_score(yx1_test, p_pred)

# %%
print(r, l, d, s, p)
# Out:
# -0.15992680348974186 -0.027993447896548895 -0.9905339841837415 -0.08802138621426536 -0.027993447896548895

# %%
cond = [(dataset['quality']>=7.5), (dataset['quality']<7.5)]
gb = ['Good', 'Bad']
dataset['review'] = np.select(cond, gb)

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  review
# 0               7.4             0.700         0.00  ...      9.4        5     Bad
# 1               7.8             0.880         0.00  ...      9.8        5     Bad
# 2               7.8             0.760         0.04  ...      9.8        5     Bad
# 3              11.2             0.280         0.56  ...      9.8        6     Bad
# 4               7.4             0.700         0.00  ...      9.4        5     Bad
# ...             ...               ...          ...  ...      ...      ...     ...
# 1594            6.2             0.600         0.08  ...     10.5        5     Bad
# 1595            5.9             0.550         0.10  ...     11.2        6     Bad
# 1596            6.3             0.510         0.13  ...     11.0        6     Bad
# 1597            5.9             0.645         0.12  ...     10.2        5     Bad
# ...

# %%
dataset['review'].unique()
# Out:
# array(['Bad', 'Good'], dtype=object)

# %%
dataset.iloc[400:450, :]
# Out:
#      fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  review
# 400            6.6             0.735         0.02  ...      9.9        5     Bad
# 401            7.7             0.260         0.30  ...     10.8        6     Bad
# 402           12.2             0.480         0.54  ...     10.5        6     Bad
# 403           11.4             0.600         0.49  ...     10.5        6     Bad
# 404            7.7             0.690         0.05  ...      9.1        5     Bad
# 405            8.7             0.310         0.46  ...     10.1        6     Bad
# 406            9.8             0.440         0.47  ...     10.8        6     Bad
# 407           12.0             0.390         0.66  ...     10.8        7     Bad
# 408           10.4             0.340         0.58  ...     11.3        6     Bad
# 409           12.5             0.460         0.49  ...      9.6        4     Bad
# 410            9.0             0.430         0.34  ...      9.5        6     Bad
# ...
